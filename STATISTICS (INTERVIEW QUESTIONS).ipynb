# %% [markdown]
# Q) What is coefficient and what is use of it in ML?
#
#
# * Coefficient represents the slope of best fit line while describe the relationship between two variables X and Y where X is independent variable and y is dependent variable.
#
#
# * Coefficient is a numerical value which used to solve the equation of linear regression and find the value of y. The equation is y = mx+c where m is coefficient or slope.
#
#
# * When we change the value of X the value of Y will also change. Coefficient is a numerical value which tells that by what unit the value of Y will change if we change the value of X.
#
#
# * For example, in the equation y = 3x + 2, the coefficient of x is 3, which means that when x increases by 1, y will increase by 3.
#
#
# * Coefficients can be positive, negative, or zero. A positive coefficient means that it is associated with an increase in the output, while a negative coefficient means that it is associated with a decrease in the output.
#
#
# * coefficients are used in regression analysis to build the relationship between variables and to make predictions.

# %% [markdown]
# Q) What is intercept and what is their use in ML? / What is intercept of coefficient?
#
#
# * If the value of x is 0 then at what point it will intercept the best fit line on y axis that point is called intercept.
#
#
# * The value of intercept will remain same in regression only the value of coefficient will change.
#
#
# * Intercept is also known as Constant. We need the value of intercept to find the value of y because y = mx+c where the c is intercept.

# %% [markdown]
# Q) What is Variance and what is their use in ML?
#
#
# * In statistics and machine learning, variance is a measure of the variability or spread of a set of data points around their mean or average value. OR
#
#
# * Variance measure how data points of dataset are spread around their mean value and what is the difference between the data points and their mean value.
#
#
# * Variance tells the difference between different datasets or different features.
#
#
# * Variance is squared difference of data points from it's mean value. The value of variance is in square.
#
#
# * In machine learning, variance can be used to evaluate the performance of a model on a training dataset, and it is used to assess how well the model generalizes to new, unseen data.
#
#
# * If a model has high variance, it means that it is overfitting to the training data, which means that it is memorizing the noise in the data rather than capturing the underlying patterns. In this case, the model may perform well on the training data but poorly on new, unseen data.
#
#
# * On the other hand, if a model has low variance, it means that it is underfitting the data, which means that it is oversimplifying the relationships between the input and output variables. In this case, the model may perform poorly on both the training data and new, unseen data.
#
#
# * To reduce variance in a model, techniques such as regularization can be used. Regularization helps to prevent overfitting by adding a penalty term to the objective function that the model is optimizing.
#
#
#
# * Variance only tells us that how the spread of data is or how a particular data is different from another data but don't give the exact value so we use standard deviation to find the exact spread of data and to find exact difference between data.
#
#
# * In summary, variance is an important concept in machine learning, as it helps to evaluate the performance and generalization ability of a model, and to identify and address problems such as overfitting and underfitting.

# %% [markdown]
# ![maxresdefault.jpg](attachment:maxresdefault.jpg)

# %% [markdown]
# Q) What are vectors and vectorization and what is their use in machine learning?
#
#
# * Vectors are mathematical objects that have both magnitude and direction, and are used to represent the direction and magnitude of data in machine learning. Vector used in many places in machine learning eg:- PCA, vectors are used to find the direction of data where maximum variance is capture and make Principal Components in that direction.
#
#
# * Vectorization is a process used to convert non-numeric data such as text, images, or audio into numeric vectors that can be processed by machine learning algorithms.
#
#
#
# * PCA works on numeric data, so before applying PCA, it is necessary to vectorize any non-numeric data in the dataset. Once the data has been vectorized, PCA can be applied to identify the directions of maximum variance in the data and reduce its dimensionality.
#
#
#
# * Vectorization used in text data. Vectorization can involve representing each document as a bag-of-words or using word embeddings to represent each word as a vector(i.e: number)
#
#
# * In summary, vectorization is not used directly in PCA, but it can be used as a preprocessing step to convert non-numeric data into numeric vectors that can be processed by PCA.

# %% [markdown]
# Q) What is the difference between regression and correlation?
#
# Regression:-
#
#
# * Regression is a statistical method that helps to predict the value of one variable based on the value of another variable.
#
#
# * It is a method to build a relationship between a dependent variable and one or more independent variables.
#
#
# * The goal of regression is to find the best-fit line that can explain the relationship between the variables.
#
#
# * It can be used to identify the strength and directional relationship between variables.
#
#
# * There are different types of regression models, such as linear regression, polynomial regression, and logistic regression.
#
#
# Correlation:-
#
#
# * Correlation is a statistical method that measures the strength and directional relationship between two variables.
#
#
# * It is a method to check whether two variables are related to each other or not, and if they related so, how strongly.
#
#
#
# * The value of correlation ranges between -1 to +1. If the value comes in negative it means there's a inverse relationship between them and if the value comes in positive it menas there's a positive relationship between them.
#
#
# * The value closer to +1 indicates the strong positive relationship and the value closer to -1 indicates the strong inverse relationship and the value is 0 it indicates there's no relationship between them.
#
#
# * There are different types of correlation, such as Pearson's correlation, Spearman's correlation, and Kendall's correlation.

# %% [markdown]
# Q) What is cumulative sum?
#
#
# * A cumulative sum also known as a running total or cumulative total.
#
#
# * It is calculated by adding each value in a sequence to the sum of previous value in the sequence.
#
#
# * The result of cumulative sum is a series of numbers. Eg:- if the sequence is {1, 2, 3, 4}, the cumulative sum would be {1, 3, 6, 10}, as value is the sum of the previous value.

# %% [markdown]
# Q) What is Euclidean Distance?
#
# * It is a statistical measure to find the shorest distance between 2 data points in a multi-dimensional space followed by a straight line between source and destination.

# %% [markdown]
# ![eyJidWNrZXQiOiJjb250ZW50Lmhzd3N0YXRpYy5jb20iLCJrZXkiOiJnaWZcL2Rpc3RhbmNlLWZvcm11bGEuanBnIiwiZWRpdHMiOnsicmVzaXplIjp7IndpZHRoIjo4Mjh9LCJ0b0Zvcm1hdCI6ImF2aWYifX0=.avif](attachment:eyJidWNrZXQiOiJjb250ZW50Lmhzd3N0YXRpYy5jb20iLCJrZXkiOiJnaWZcL2Rpc3RhbmNlLWZvcm11bGEuanBnIiwiZWRpdHMiOnsicmVzaXplIjp7IndpZHRoIjo4Mjh9LCJ0b0Zvcm1hdCI6ImF2aWYifX0=.avif)

# %% [markdown]
# Q) What is Manhattan Distance?
#
# * Manhattan Distance is a statistical measure to find the distance between 2 data points in a multi-dimensional space by summing the absolute difference between each coordinate of 2 points.
#
#
# * It is named after the way streets in Manhattan are laid out in a grid-like pattern, where the distance between 2 points is the sum of the lengths of the blocks they are on.
#
#
# Formula:-
#
#
# Manhattan Distance(x,y) = | x 1 − x 2 | + | y 1 − y 2 |

# %% [markdown]
# ![image-3-1024x367.png%20%281%29.webp](attachment:image-3-1024x367.png%20%281%29.webp)

# %% [markdown]
# Q) Difference between Euclidean Distance and Manhattan Distance?
#
# * The main difference between Euclidean distance and Manhattan distance is that Euclidean distance gives more weight to differences between large values, while Manhattan distance gives equal weight to all differences.
#
#
# * Euclidean distance is more sensitive to outliers than Manhattan distance, which makes it more suitable for continuous variables, while Manhattan distance is more suitable for discrete variables.
