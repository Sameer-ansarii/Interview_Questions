# %% [markdown]
# ### Q) What is Statistics?
#
#
# Statistics is the science and a branch of mathematics which deal with collecting, organizing, analzsing and interpreting the data.

# %% [markdown]
# ### Q) What is data?
#      Data are facts or peice of information.

# %% [markdown]
# ### Q) What is Descriptive statistics?
#
# * Descriptive statistics are used to organize, summarize and analyize the data that is collected.
#
#
# * Descriptive statistics include measures of central tendency (mean, median, mode) and measures of dispersion (range,variance, standard deviation).

# %% [markdown]
# ### Q) What is Inferential statistics?
#
# * Inferential statistics are used to make inferences (conclusion) about populations based on samples.
#
#
# * In inferential statistics we find some measuremnets from sample, such as mean, median, standard deviation etc. and by using these measurements we perfrom some experiments or tests and on the basis of these tests we make inference about the population.
#
#
# * Inferential statistics include hypothesis tests, confidence intervals, and p-values.

# %% [markdown]
# ### Q) What are Scalars?
#
# * Scalar are quantities that can be fully described by a magnitude alone.
#
#
# * Any quantity which can be describe by a numerical value whether it is positive or negitive is known as scalar, where the numerical value is known as magnitude.
#
#
# * EG- My office is 10 kms far away. 10 is the magnitude and km is the quantity.

# %% [markdown]
# ### Q) What are vectors and their uses in ML?
#
# * Vectors are quantites which describes both magnitude or direction of a quantity.
#
#
# * The quantities which requires 2 measurements to describe them, magnitude and direction is known as vectors.
#
#
# * A vector is a 1 dimensional array in computer science which consists of elements of same type.
#
#
# * Eg:- My office is 10 km far away in north-east direction from the initial point. 10 is the magnitude, km is the quantity and north-east is the direction.
#
#
# Uses:-
#
# * Each data point in (x,y) cordinate system is represent as a vector.
#
#
# * Vectors can be used to find the similarity between data points by measuring the angle between their vectors. The smaller the angle, the more similar the data points are.
#
#
# * Vectors can be used at many places in ML, such as PCA.

# %% [markdown]
# ### Q) What is vectorization?
#
# * Vectorization is a process to convert non-numeric data such as text, images, or audio into numeric vectors that can be processed by machine learning algorithms.

# %% [markdown]
# ### Q) What is cosine similarity and their uses in ML?
#
# * Cosine similarity is a measure of similarity between 2 data points in a multi-dimensional space.
#
#
# * Cosine similarity is the angle between vectors in a vector space.
#
#
# * Cosine similarity doesn't depend on the magnitude of the vectors, it's only depends on angle between vectors.
#
#
# * It is calculated by taking the dot product of the vectors and dividing it by the product of their lengths.
#
#
# * The value of cosine similarity ranges between 0-1. The value closer to 1 indicates the more similarity between vectors and the value closer to 0 indicates the more disimilarities between vectors.
#
#
# Uses:- Cosine similarity can be used to measure the similarity between two data points, two variables in a dataset, two images, two pieces of text, or two other types of data.
#
#
# Formula:- Cos(x, y) = x . y / ||x|| * ||y||
#
# where,
#
# x . y = product (dot) of the vectors ‘x’ and ‘y’.
#
#
# ||x|| and ||y|| = length of the two vectors ‘x’ and ‘y’.
#
#
# ||x|| * ||y|| = cross product of the two vectors ‘x’ and ‘y’.
#
#
# * The cosine similarity between two vectors is measured in ‘θ’.
#
#
# * If θ = 0°, the ‘x’ and ‘y’ vectors overlap, means they are similar.
#
#
# * If θ = 90°, the ‘x’ and ‘y’ vectors are dissimilar.

# %% [markdown]
# ### Q) What is Euclidean Distance?
#
# * It is a statistical measure to find the shorest distance between 2 data points in a multi-dimensional space followed by a straight line between source and destination.

# %% [markdown]
# ![eyJidWNrZXQiOiJjb250ZW50Lmhzd3N0YXRpYy5jb20iLCJrZXkiOiJnaWZcL2Rpc3RhbmNlLWZvcm11bGEuanBnIiwiZWRpdHMiOnsicmVzaXplIjp7IndpZHRoIjo4Mjh9LCJ0b0Zvcm1hdCI6ImF2aWYifX0=.avif](attachment:eyJidWNrZXQiOiJjb250ZW50Lmhzd3N0YXRpYy5jb20iLCJrZXkiOiJnaWZcL2Rpc3RhbmNlLWZvcm11bGEuanBnIiwiZWRpdHMiOnsicmVzaXplIjp7IndpZHRoIjo4Mjh9LCJ0b0Zvcm1hdCI6ImF2aWYifX0=.avif)

# %% [markdown]
# ### Q) What is Manhattan Distance?
#
# * Manhattan Distance is a statistical measure to find the distance between 2 data points in a multi-dimensional space by summing the absolute difference between each coordinate of 2 points.
#
#
# * It is named after the way streets in Manhattan are laid out in a grid-like pattern, where the distance between 2 points is the sum of the lengths of the blocks they are on.
#
#
# Formula:-
#
#
# Manhattan Distance(x,y) = | x 1 − x 2 | + | y 1 − y 2 |

# %% [markdown]
# ![image-3-1024x367.png%20%281%29.webp](attachment:image-3-1024x367.png%20%281%29.webp)

# %% [markdown]
# ### Q) What is Calculus and their uses in ML?
#
#
# * Calculus is a branch of mathematics that deals with the study of change. It has two branches: differential calculus and integral calculus.
#
#
# * Calculus helps in to find the relationship between 2 variables (quantities) by measuring how one variable change when there is a change in another variable and how these changes happens over time.
#
#
# * Calculus is divided into two main branches: differential calculus and integral calculus.
#
# Uses:-
#
# * Calculus is used to find the relationship in linear as well as in non-linear variables.
#
#
# * Calculus can be used to find the relationship between two variables, even if the relationship is non-linear. For example, calculus can be used to find the relationship between the price of a product and the quantity of the product that is demanded. The relationship between these two variables is non-linear, because the demand for a product decreases as the price of the product increases.

# %% [markdown]
# ### Q) What is slope or gradient or coefficient and it's use in ML?
#
# * The rate of change between two variables is known as slope or gradient or coefficient.
#
#
# * Slope or rate of change or coefficient means when the value of one variable is changing then how much the value of second variable will change.
#
#
# * Eg:- If the slope is 2, it means that for every one-unit increase in the independent variable (X), the dependent variable (Y) will increase by 2 units. Similarly, if the slope is -0.5, it means that for every one-unit increase in the independent variable(X), the dependent variable will decrease by 0.5 units.
#
#
# Uses in ML:-
#
#
# * It is used in Gradient Descent Algorithm in Linear Regression to find the value of (Y) variable.
#
#
# * It is used in Deep Learning as well in neural networks.

# %% [markdown]
# ### Q) What is intercept or constant or intercept of coefficient and what is their use in ML?
#
# * Constant or intercept refers to the value where a regression line or curve crosses the y-axis.
#
#
# * If the value of X is 0 then at what point the best fit line intersects on Y axis, that point is called intercept or constant or intercept of coefficient.
#
#
# * The value of constant is remain same in linear regression.
#
#
# Use of Constant / intercept / intercept of coefficient:-
#
#
# * It is used to find the value of Y variable in linear regression.

# %% [markdown]
# ### Q) What is Loss Function or Error Function and their use in ML?
#
#
# * Loss Function measures the error (difference) between actual value and the predicted value of a machine learning model.

# %% [markdown]
# ### Q) What is Cost Function?
#
# * Cost Function is similar to Loss Function the difference between them is when we measure the error (difference) of a individual observation it is known as Loss Function and we measure the overall error of a model it is known as Cost Function.
#
#
# * Cost Function is calculated by averaging the loss function for all observations in a dataset.

# %% [markdown]
# ### Q) What is the use of Loss & Cost Function in ML?
#
#
# Use of Cost Function in ML:-
#
# * Cost function: The cost function is a measure of the overall error of a model. It is typically calculated by averaging the loss functions for all of the observations in the dataset. The cost function is used to train a machine learning model by minimizing the error. This is done through a process called gradient descent, which iteratively updates the model's parameters to reduce the cost. As the cost decreases, the model's predictions become more accurate.
#
#
# * Optimization during Training: Cost Functions are used to optimize the performance of a ML model during trainning. It's means our primary goal is to reduce the cost function or error function during trainning pharse of ML model. This is done through a process called gradient descent.
#
# Use of Loss Function in ML:-
#
# * Loss function: The loss function is a measure of the error of an individual observation. It is typically calculated as the difference between the predicted value and the actual value. The loss function is used to evaluate the performance of a machine learning model. A lower loss indicates that the model is performing better.
#
#
# * Evaluation of Model Performance: Loss Functions are used to evaulate the performace of a machine learning model. Their are several Loss Functions in Machine Learning like MSE, MAE, RMSE.
#
#
# Note:- Cost & Loss Function are used in many algorithms of ML.

# %% [markdown]
# ### Q) What is Global Minima?
#
# * Global Minima is a point where the value of cost function is minimum.
#
#
# * Our aim is to find the global minima to optimize our model performance which helps in to make better predictions and increase the accuracy of our model.
#
#
# * There are various algorithms to find global minima , but we usually use gradient descent algorithm.

# %% [markdown]
# ### Q) What is Gradient Descent?
#
# * Gradient Descent is an iterative algorithm which is used to find the global minima, global minima is the point and value where the cost function is minimum, it helps to optimize the model and enhance it's performance.
#
#
# * Gradient Descent is an optimization technique used to optimize the performance of model by minimizing cost function.
#
#
# * Gradient Descent is an iterative algorithm which starts by finding the gradient for a random point in the vector of gradient against the cost function and steeps down iteratively according to the learning rate, this process is repeated untill it finds the global minima.

# %% [markdown]
# ### Q) What is Matrix?
#
#
# * Matrix is a rectangular array of numbers arranged in rows and columns. Each number in the matrix is called an element. A matrix contains elements of the same data type.
#
#
# * In a matrix, column elements are arranged vertically, and row elements are arranged horizontally. For example, a matrix with 3 rows and 4 columns is called a 3x4 matrix.
#
#
# * We can perform various mathematical operations between elements of a matrix and between two or more matrices, such as addition, subtraction, multiplication, and division.

# %% [markdown]
# ### Different Types of Matrix

# %% [markdown]
# ![1.jpg](attachment:1.jpg)

# %% [markdown]
# ### Q) What is Transpose Matrix?
#
#
# * It is matrix that interchange the position of rows and columns. It means column values shows horizontally and row values show vertically.
#
#
# * In PCA transpose matrix of covariance is help to find the eighenvalues and eighenvectors.

# %% [markdown]
# ![download.jpeg](attachment:download.jpeg)

# %% [markdown]
# ### Q) What is Sparse Matrix?
#
# * It is a matrix where maximum elements are zero, means it contains maximum null values.
#
#
# * Sparse matrix used at many places in data science like recommendation system, nlp, etc.
#
#
# * In Recommendation system it is used to create a User Item Interaction Matrix,  representing the interactions between users and items.

# %% [markdown]
# ### Q) What is Identity Matrix?
#
# * It is a matrix where all the diagonal elements are one and remaining other elements are zero.

# %% [markdown]
# ### Q) What is population (N)?
#
# * Population is the group that we are interested in studying.

# %% [markdown]
# ### Q) What is sample (n)?
#
# * Sample is a subset of population. Eg:- Media conduct exit polls before the result of election to predict the result by taking the opion of sample of a population.
#
#
# * Sample are in statistics to make inference (conclusion) about a population.

# %% [markdown]
# ### Q) What are the different types of sampling techniques?
#
# Sampling techniques are used to collect samples from a population. The goal of sampling is to create samples that represents the entire population.
#
# 1) Simple Random Sampling :- In simple random sampling we collect samples randomly, it means every person has an equal chance to select as a sample.
#
#
# 2) Stratified sampling: In stratified sampling we first categorize the entire population than collect the samples from the selected group.
#
#
# 3) Systematic sampling: In systematic sampling every kth member is selected as a sample. For example the entire population is 1000 and you have to collect only 100 samples than you have to collect samples from every 10th person.
#
#
# 4) Convenience Sampling :- In convience sampling samples are collected based on convenience and accessibility, it means we collect samples from that individuals who are easily available.
#
#
# 5) Cluster Sampling: In cluster sampling we first make clusters of entire population than collect samples from random clusters.

# %% [markdown]
# ### Q) What is variable and it's type?
#
# * Variable is a property that takes many values whether it is numeric or categorical.
#
# There are two types of Variables:-
#
# 1) Quantitative Variable / Numerical Variable: Quantitative Variable consists only numerical values. Quantitative Variable are categorize into two subtypes:-
#
# a) Discrete Variable: Discrete Variable only consists whole number not float. Eg: No. of students in a classroom or No. of cars in a family.
#
#
# b) Continuous Variable: Continuous Variable consists whole number as well as float. Eg: Height, Weight, etc.
#
#
# 2) Qualitative Variable / Categorical Variable: Qualitative Variable consists only categorical values. Qualitative Variable are categorize into two subtypes:-
#
#
# a) Nominal Variable: Nominal variables have categories without any order or hierarchy. Eg:- Gender is a Variable which which consists only 2 values, such as male and female, or address variable where we have multiple categories.
#
#
# b) Ordinal Variable: Ordinal variable have categories with order and heirarchy. Eg:- Education Level is variable which consists 3 categories, such as undergraduate, graduate, post-graduate, Rating Variable which consists 1-5 star rating.

# %% [markdown]
# ### Q) What is distribution?
#
# * Distribution means how much data is present in between a specific range.

# %% [markdown]
# ### Q) What is Measure of Central Dendency and use of it?
#
# A measure of Central Dendency is a single value that represents the centre of the data. There are three main measures of central tendency:-
#
#
# 1) Mean:- Mean is average value of the data. Mean is calculated by - sum of all values / total number of values.
#
#
# 2) Median:- Median is the centre value of the data, which can be find by - First arrange all the values in ascending order, if the total number of values is odd, the median is the middle value. If the total number of values are even then take two centre values and divide by 2, the value comes after is the median. The median is also known as the 50th percentile value, which means that 50% of the records are below and 50% are above the value of the median.
#
#
# 3) Mode:- The most frequent value in data is known as mode. When the data has more than one most frequent value, it is known as multi-modal data.
#
# Uses:-
#
# * Measure of Central Dendency are used to fill the 'NaN' values in the data.
#
#
# *  Measure of Central Dendency are used to get insights from the data.

# %% [markdown]
# ### Q) What is weighted mean?
#
# * We use weighted mean when each data point has different weightage and importance in data. Weighted mean is calculated by multiplying each data points by its weightage in the data, then add all the products and divide it by total number of data points.

# %% [markdown]
# ### Q) If the data contains outliers than it will effect the measures of central dendency or not?
#
# * Outliers only effects on mean not on medain and mode. If the outliers are present the value of mean is increases or decreases and do not gives the accurate average value of the data.

# %% [markdown]
# ### Q) What are outliers?
#
# * Outliers are the values which are significantly different from the other values of the data, whether they are extremely high or extremely low value. Outliers do not follow the range and pattern of the data.

# %% [markdown]
# ### Q) What is parameter and statistic?
#
# * Parameters is a numerical value that describe the characteristics of a population, such as the total count of a population,  mean of the population, variance of the population, standard deviation of a population etc. Parameter are represents in greek letters, such as sigma for standard deviation, mu for mean etc.
#
#
# * Statistic is a numerical value that describe the characteristics of a sample, such as the total count of a sample, mean of the sample, variance of the sample, standard deviation of a sample etc.
#
#
# Note:- With the help of statistic we estimiate the parameter. Eg: We first find the sample mean and according to that we estimate the population mean.

# %% [markdown]
# ### Q) What is measures of dispersion ?
#
# Measure of Dispersion describe that how much the data points are far from the mean value. We have three main measures of dispersion.
#
# 1) Range:- Range describes the minimum and maximum value of the data. The range is calculated by taking the difference between the maximum and minimum values of a data
#
#
# 2) Variance:- Variance is a measure to check the spread of data and their distribution. A high variance indicates that the data is spread out over a wide range, while a low variance indicates that the data is concentrated around the mean. It is calculated by taking the average of the squared differences between each data point and the mean value. The value of variance is in square form.
#
#
# 3) Standard Deviation: Standard deviation is a measure to check the spread and distribution of data around it's mean. Standard deviation is the square root of variance. Standard deviation is use to normalize the value of variance.
#
# * Standard deviation has a concept of Z-Score which is also known as empirical rule or empirical formula use to understand the distribution of data based on standard deviation, which says that our data is present in between -3 to +3 standard deviation range where 68% data present between -1 to +1 standard deviation range, 95% data present between -2 to +2 standard deviation range, 99.7% data present between -3 to +3 standard deviation range and remaining 0.3% data present outside the -3 to +3 standard deviation range and consider as outliers.

# %% [markdown]
# ### Formula of Variance:-

# %% [markdown]
# ![population-variance.png](attachment:population-variance.png)

# %% [markdown]
# ### Q) What are the uses of measures of dispersion?
#
# Use of Measure of Dispersion:-
#
# 1) Variance and standard deviation can be used to compare two or more numerical variables of the same or different datasets.
#
#
# 2) We can check the distribution of data by using range, interquartile range, and standard deviation.
#
#
# 3) We can identify outliers using Z-Score concept of standard deviation.
#
#
#
# 4) We can gain insights from the data using all measures of dispersion.
#
#
# 5) We can compare same variable in different datasets by using variance and standard deviation.
#
#
# 6) We can evaluate the performance of model on different data sets by using variance. We have to compare the variance of predicted variable of each dataset. If the variance is low between every dataset, the model is considered to be good.
#
#
# 7) We can compare different populations in the data using variance and standard deviation. For example, if we compare the heights of male and female students in a school, and the variance is more for the heights of male students, it means that the heights of male students are more than the heights of female students.

# %% [markdown]
# ### Q) What is Histogram?
#
# * A histogram is a graph that represents the distribution of data within a specific range. The width of each bin represents the range size, and the height of each bar represents the number of data points within a specific range.
#
#
# * While making a histogram we first decide the number of bins. No. of Bins means in how ranges the data will seprate. Usually we take bin size as 10 or any smaller number because small number of bins are easy to interpret.
#
#
# * It is use to see the distribution of data within specific ranges and gain insights from them.

# %% [markdown]
# ### Q) What is Bar Graph?
#
# * Bar graph also known as bar chart, represents the value counts of each category present in the variable. Each bar represents a particular category of the variable.

# %% [markdown]
# ### Q) What is KDE and their use?
#
# KDE stands for Kernel Density Estimator, it is a graph that represents the distribution or variability of the data within specific ranges. The smooth curve represents the distribution or variability of the data, the width of the bar represents the specific range, and the height of the bar represents how many data points falls under this specific range.
#
# Uses:-
#
# * It is use to see the distribution or variability of data within specific ranges.
#
#
# * It is also use to compare the distribution or variability of 2 variables along with their specific ranges, in a single graph and gain insight through it.

# %% [markdown]
# ### What is Percentage?
#
# * Percentage is numerical value that represents a part or proportion of whole term out of 100. The range of percentage is 0-100. Percentage is denoated by percent sign (%).

# %% [markdown]
# ### Q) What is percentile?
#
# Percentile is a numerical value that desribes the position of a specific value, in the data while comparing to the other values of the data. Eg:- A student scores 90 %tile in exams, it means it scores equal to or above than 90% students. The range of percentile is 0-100. Percetile is calculated by, No. of data points below x / Total No. of data points* 100.
#
# Uses:-
#
# * Percentiles are used to analyze the distributions of data.
#
#
# * Identify outliers
#
#
# * Check the position of a specific value among all values.

# %% [markdown]
# ### Q) What is Quartile?
#
# The range of percentile (0-100) is divided into 4 equal ranges:-
#
# 1) Quartile 1 (Q1):- (0-25) percentile range, it indicates that 25% of data is below this point.
#
#
# 2) Quartile 2 (Q2):- (26-50) percentile range, it indicates that 50% of data is below this point. Q2 or 50 percentile value is also known as median of the data.
#
#
# 3) Quartile 3 (Q3):- (51-75) percentile range, it indicates that 75% of data is below this point.
#
#
# 4) Quartile 4 (Q4):- (76-100) percentile range, it indicates that 100% of data is below this point.
#
#
# USe:- Quartile are used to identify the distribution and variability of the data within a specific range.

# %% [markdown]
# ### Q) What is IQR and IQR Method?
#
#     * The interquartile range (IQR) is the range between 25th to 75th percentile. It is calculated by Q1-Q3.
#
#     * IQR is a method use to identify outliers with the help of 5 point summary, lower fence and upper fence.

# %% [markdown]
# ### Q) What is five point summary?
#
#     The five points summary is a descriptive statistical summary of data use to make boxplot. Five point summary contains    five things:-
#
#     1) Minimum Value of the data.
#
#     2) 25th percentile value / Quartile 1 value / first quartile value
#
#     3) 50th percentile value / Quartile 2 value / second quartile value / median
#
#     4) 75th percentile / Quartile 3 / thrid quartile value
#
#     5) Maximum value of data

# %% [markdown]
# ### Q) What is lower fence and upper fence?
#
# * Lower fence and upper fence are the thresholds to identify outliers or we can say that it is a range of valid data. The values which are below the lower fence and above the upper fence consider as outliers.
#
#
# * We can find the value of lower fence in data by - Lower Fence = Q1 - 1.5 * IQR
#
#
# * We can find the value of upper fence in data by - Upper Fence = Q3 + 1.5 * IQR

# %% [markdown]
# ### Q) What is boxplot?
#
# * A box plot is also known as whisker plot, which represents the min value (excluding outlier), Quartile 1, Quartile 2 (median), Quartile 3 and max value (excluding outlier).  Boxplot is a visual representation of IQR Method.
#
#
# * Box plot provides a visual statistical summary of the data.
#
# * The horizontal lines which are outside the box is known as whisker.
#
#
# Uses:-
#
# * Boxplot is use to check the skewness of data and identifying outliers.

# %% [markdown]
# ![box-whisker-plot%20%281%29.webp](attachment:box-whisker-plot%20%281%29.webp)

# %%
import seaborn as sns

# Sample data
data = [1,2,2,2,3,3,3,4,5,5,5,6,6,6,6,7,8,8,8,9,27]

# Create a box plot
sns.boxplot(x = data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Q) Which method is best or suitable to detect outliers, Z-Score or IQR Method?
#
# * I would first go with IQR Method and check the percentage of outliers if the percentage of outliers are high so, I will go with Z-Score method. Z-Score method follows the empricial rule of standard deviation, according to that only 0.3% of data is consider as outliers.
#
#
# Note:  It is recommended to check the values of variable before perfrom any function and correct it, in case of wrong values are present in the variable. Eg: If you have a variabe like age where we have some wrong values, such as -15,-25 and our IQR method defines a range between -5 to +70, then it will consider wrong values as valid data.

# %% [markdown]
# ### Q) What is Normal Distribution?
#
# Normal Distribution is also known as gaussian distribution. It has some characteristics which are:-
#
# 1) Data is symmetric around the mean, it means the value of mean and median is same. In distribution graph the data present at the left side of the mean is equivalent to the data present at the right side of the mean.
#
#
# 2) The total area under the curve of distribution is 1. If we find any specific area under the curve, the formula will be 1-remaining area.
#
#
# 3) Normal Distribution follows the empricial rule of standard deviation which means the range of data is ranges between -3 to +3 standard deviation. Our 68% of data will falls under -1 to +1 standard deviation range, 95% of data falls under -2 to +2 standard deviation range, 99.7% data falls under -3 to +3 standard deviation range and remaining 0.3% data is consider as outliers.
#
# Use:- Normal Distribution is used to check the distribution of data within a specific range and use to identify outliers.

# %% [markdown]
# ### Q) What is skewness?
#
# Skewness is the measure of asymmertic distribution of data. Asymmetric distribution and skewness means when the data is not normally distributed and their mean and median are not equal. There are 2 types of skewness right sweekness / positive skewness and left skewness / negitive skewness.
#
# #### OR
#
#
# skewness represents the distribution of data when it is not normally distribiution.  I means when the data is skew the mean of data is not present at centre and mean and median of data are different.

# %% [markdown]
# ### Q) What is right or positive skewness?
#
# * Right skewness, also known as positive skewness. It occurs when majority of the data points are the lower values.
#
#
# * In case of right skewness the mean is greater than the median.
#
#
# * Another reason for right skewness is the presence of outliers, which are higher values that pull the mean towards the right side.
#
#
# * For example, in an income variable, if the majority of people have lower incomes but there are a few individuals with significantly higher incomes, it can lead to right skewness.

# %% [markdown]
# ### Q) What is left or negative skewness?
#
# * Left skewness, also known as negative skewness. It occurs when majority of the data points are higher values.
#
#
# * In case of left skewness the mean is smaller than the median.
#
#
# * Another reason for left skewness is the presence of outliers, which are lower values that pulls the means towards the left side
#
#
# * Eg:- We have variable of test scores where the majority score are higher values, and very few students have low scores, it can lead to left skewness.

# %% [markdown]
# ![skewness9001268247718463390.png](attachment:skewness9001268247718463390.png)

# %% [markdown]
# ### Q) What is kurtosis and their use?
#
# Kurtosis refers to the degree of peakedness of a distribution curve. It indicates how much data is concentrated around the mean of the distribution.

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# ### Q) What are the implications / impact of skewness for data analysis?
#
# * If the skewness is present in the data than mean is not the appropriate measure of central tendency in this case we refer  median of the data.
#
#
# * Skewness mislead the reult of hypothesis tests and P-value is also not accurate.
#
#
# * When the data is skewed it will biased the result of ML model. Suppose, model was trainned on significantly high values of independent variables, so if we give the lower value of independent variable, it will not provide accurate result because, it biased towards the higher value of independent variable.

# %% [markdown]
# ### Q) How can skewness be reduced?
#
# * Skewness of data will reduce when we transform the data using standard scaler or use various transformation techniques, such as Logarithmic Transformation, Square Transformation, Square Root Transformation, Box-Cox Transformation, etc.

# %% [markdown]
# ### Q) How to check the skewness of data?
#
# There are two methods to check the skewness of data:-
#
#
# 1) Df.skew() is a inbuild function in pandas to check the skewness of data. When the value comes between -0.5 to +0.5, it means their is no skewness in data. When the value comes between -1 to +1 it means their is moderate skewness in data. When the value comes above +1 it means their is negative skewness or left skewness in data. When the values comes below -1 it means their is positive or right skewness in data.
#
#
# 2) We can visually check the skewness of data by plotting it on graphs, such as QQ Plot, Box Plot, KDE Plot, etc.
#
# Note:- The best way is using df.skew() function.

# %% [markdown]
# ### Q) What is distribution?
#
# Distribution refers to how data is spread out or distributed around the mean.

# %% [markdown]
# ### Q) What is Standard Normal Distribution?
#
#
# * Standard normal distribution is when the mean of the data is 0 and standard deviation is 1. In Standard normal distribution the mean is symmetric around the mean same as normal distribution.
#
#
# * We can convert the standard normal distribution to normal distribution using Z-Score. The Converting formula of Z-Score is (xi-mu) / standard deviation.

# %% [markdown]
# ### Q) Difference between Normal Distribution and Standard Normal Distribution?
#
# * In normal Distribution the mean is any value, such as 50,50000,5000000 but in Standard normal distribution mean is always 0.
#
#
# * In normal Distribution the data ranges between any range, such as -infinity to +infinity but in Standard normal distribution the range of data is -3 to +3, data points which are outside this range consider as outliers.
#
#
# * We can convert the normal distributed data to standard normal distributed using Z-Score. The Formula of Z-Score is (xi-mu) / standard deviation.

# %% [markdown]
# ### Q) What is Z-Score?
#
# * Z-Score is a measure to find how many standard deviation, a particular data point is far away from the mean of the distribution.
#
#
# * Z-Score of a value is find by using formula of Z-Score, which is Z = (x - μ) / σ.
#
#
# * If the data doesn't contain outliers the value of Z-Score always ranges between -3 to +3 range.
#
#
# * Z-Score is used to transform the data using Standard Scaler.

# %% [markdown]
# ### Q) What is Standardization / Z-Score?
#
# * Standardization is a feature scaling technique that is use to transform data and change it's range between -3 to +3 if data doesn't contain outliers.
#
#
# * Standard scaler helps in to change the mean of the data to 0 or around 0, which is usefull for many ML algorithms such as PCA.
#
#
# * Standardization use standard scaler to transform data. Standard scaler calculates Z-Score for each data point.
#
#
# * If our data doesn't contain outliers then the range of Z-Score and standard scaler is always ranges between -3 to +3 range.

# %% [markdown]
# ### Q) What is Normalization?
#
# * Normalization is a feature scaling technique that is used to transform data and change it's range between 0-1.
#
#
# * Normalization use min-max scaler. The formula of min max scaler is - x_scaled = x - min value / max value - min value
#
# where,
#
# x = original value
#
#
# min = minimum value of data
#
#
# max = maximum value of data

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# ### Q) When to use standard scaler and min_max scaler?
#
# * When we have the prior knowledge of minimum and maximum value of the variable, such as age, height, weight etc. in this case we apply min_max scaler otherwise we use standard scaler.
#
#
# * We have many algorithm in Data Science which usually perform better with standard scaler such as PCA. By applying the standard scaler mean of the data will changes to 0 or around 0.
#
#
# * There is no fix rule in data science to apply min_max scaler or standard scaler at particular places. We have to apply both and check the results, which scaler gives better gives better result go with that.

# %% [markdown]
# ### Q) What is covariance?
#
#
# * It is a statistical measure to find the directional relationship between two variables. Value of covariance ranges between -infinity to +infinity.
#
#
# * If the value comes in +, it means variables have positive directional relationship, which means when the value of any variable is increases then the value of second variable is also increases.
#
#
# * If the value comes 0, it means there is no directional relationship between variables.
#
#
# * If the value comes in -, it means variables have negitive or inverse directional relationship, which means when the value of any variable is increases then value of second variable will decreases.

# %% [markdown]
# Formula
#
# ![Covariance-Formula.png](attachment:Covariance-Formula.png)

# %% [markdown]
# ### Q) What is Correlation / Pearson's Coefficient Correlation?
#
#
# * It is a statistical measure to find the directional relationship between variables along with the strength of directional relationship. The value of correlation ranges between -1 to +1. It is also known as Pearson's Coefficient Correlation.
#
#
# * The value closer to -1 indicates the strong negitive or inverse correlation.
#
#
# * The value 0 indicates there is no correlation between variables.
#
#
# * The value closer to +1 indicate the strong positive correlation.
#
#
# * Formula of Pearson's Coefficient Correlation is - Cov(x,y) / standard deviation of x * standard deviation of y

# %% [markdown]
# ### Q) What is Spearman's Rank Correlation?
#
#
# * Spearman's Rank Correlation is used to find the correlation between variables which are showing the Rank of Something. Eg: Education status variable which have three categories: undergraduate, graduate, post-graduate and we have employement status variable which have 3 categories: unemployed, employed, self-employed.
#
#
# * Spearman's Rank Correlation is used to find the correlation between that type of variables, which do not having a linear-relation or sort of linear relationship and showing rank of something.
#
#
# * Rank showing variables are called as ordinal variables. Spearman's Rank Correlation perform effective with ordinal variables.
#
#
# * Range of Spearman's Rank Correlation is ranges between -1 to +1.
#
#
# * Formula - cov(R(x), R(y) / standard deviation of R(x) * standard deviation of R(y).

# %% [markdown]
# ### Q) What is multi-colinearity?
#
# * When 2 or more independent variables are highly correlated with each other in regression analysis, it is called multi-colinearity. To avoid from this problem we drop features which are highly-correlated.

# %% [markdown]
# ### Q) What is the difference between covariance matrix and correlation matrix?
#
#
# * Covariance Matrix: A covariance matrix is a matrix that shows the variance and covariance between each pair of variable . Diagonally it shows the covariance between each pair of variables and off-diagonally it shows the variance of each variable. Covariance measures the directional relationship between each pair of variables whether it is positive or inverse. The value of covariance ranges between -infinity to +infinity. Covariance matrix usually use in PCA to compute eighen values nd eighen vectors.
#
#
# * Correlation Matrix: A correlation matrix is a matrix that shows the correlation between each pair of variables. Correlation measures the strength of directional relationship between variables whether it is positive or inverse. The value of correlation ranges between -0 to +1. Correlation matrix is usually use to select features for model trainning.

# %% [markdown]
# ### Q) What is the difference between regression and correlation?
#
# * Regression is statistical method to predict or find the value of target variable by using the value of gradient, intercept and  values of independent variables. Regression builds a relationship between all independent variables and dependent variable. We have various types of regression, such as Linear Regression and polynomial Regression, etc. Regression minimizes the sum of squared error to predict the value of target variable.
#
#
# * Correlation is a statistical method to find the strength and directional relational between 2 variables. The value of correlation ranges between -1 to +1. The value closer to -1 indicates strong inverse directional relatinship between variable while value closer to + indicates strong positive directional relationship between variables and when the value is 0 it means there is no relationship between variables. We have various types of correlation, such as Pearson's Correlation, Spearman's Rank Correlation, etc.

# %% [markdown]
# ### Q) What is the difference between causation and correlation?
#
# * Causation refers to the relationship between variables. Causation says that when the value of one variable is change then the value of another variable is also changes. It is not related to correlation, correlation only tells the strength and directional relationship between variables but it doesn't mean that 2 variables are related to each other and if the value of one variable is change then the value of another variable is also change. For example:- We have 2 variables in a dataset which are ice cream sales and Shark Attack, lets suppose these 2 variables are highly correlated that doesn't mean that they are related to each other and ice cream sales depends on sahrk attack.

# %% [markdown]
# ### Q) What is sample distribution?
#
# * In sample distribution we first take random multiple subsets of sample from population of equal sizes and then compute their means or any other statistical measure and then check its distribution, that distribution is known as sample distribution.
#
#
# * If we take means of all subsets, it is called sample mean distribution.

# %% [markdown]
# ![maxresdefault.jpg](attachment:maxresdefault.jpg)

# %% [markdown]
# ### Q) Use of Sample distribution?
#
# * Sample distribution used to conduct various hypothesis tests.

# %% [markdown]
# ### Q) What is central limit theorem?
#
# * The Central Limit Theorem states that as we increase the numer of sample sizes and number of sample subsets then sample mean distribution will tends towards the normal distribution, no matter how is the distribution of population it means as we increase the number of sample sizes and the number of sample subsets, the mean of the sample distribution comes closer towards the center of the distribution.
#
#
#
# * Central limit theorem assumes that number of sample sizes is 30 or greater than 30 otherwise central limit theorem can't perform well.
#
#
# * Central Limit Theorem also states that the sample mean is very closer to the population mean.
#
#
# * Central limit theorem is used to perform various hypothesis tests.

# %% [markdown]
# ### Q) What is statistical inference?
#
# * Statistical inference means to conclude something about the population on the basis of sample data. We have 2 type of statistical inferences:-
#
# 1) Estimation
#
# a) Point estimation
#
# b) Interval estimation
#
#
# 2) Hypothesis testing

# %% [markdown]
# ### Q) What is standard error?
#
# * Standard error is the standard deviation of a sample statistic distribution, such as the mean. A larger standard error indicates a larger difference between the sample statistic and the population parameter, while a smaller standard error indicates a smaller difference.
#
#
# Note:- Standrad error states that larger the sample size lesser the stand error.

# %% [markdown]
# ![Standard-error-formula.webp](attachment:Standard-error-formula.webp)

# %% [markdown]
# ### Q) What is point estimate?
#
#
# * Point estimate is single numerical value which indicates our assumption about the population parameter.
#
#
# * Point estimate is used to find confidence inteval, we add and subtract the margin of error from point estimate to calculate confidence interval.
#
#
# * Point estimate is a single numerical value which represents the sample.
#
#
#
# Note: We use Point estimation because it is very hard or impossible to gather data of whole population, so we use sampling and calculate sample statistic(such as mean) and on the basis of sample statistic we try to estimate the same population parameter.

# %% [markdown]
# ### Q) What is Interval estimation?
#
# * In Interval estimation we have to calculate 2 numerical values which is lower limit and upper limit.
#
#
# * Lower limit and upper limit defines a range where our assumed value about the population parameter will likely to lie.

# %% [markdown]
# ### Q) What is confidence interval?
#
# * Confidence interval is a range which indicates that our assumed value about the population parameter is likely to fall in this range. Confidence interval is denoted as 1-alpha.
#
#
# * We usually take 95% as confidence interval it means there is 95% probability that our assumed value about the population parameter will likely to fall in this range.
#
#
# * Confidence interval is calculate by using point estimate, sample mean, sample standard deviation, sample size, confidence level and margin of error.
#
#
# * We add and subtract the point estimate with error of margin to find confidence interval.
#
#
# * As we increase the confidence level the range of confidence interval will also increases.

# %% [markdown]
# ### Q) What is confidence level?
#
# Confidence level is the surety percentage. If confidence level is 95%, it means I'm 95% sure that my estimated value about the population parameter will likely to fall under the confidence interval range.

# %% [markdown]
# ### Q) What is margin of error?
#
#
# * Error of margin is a probability which indicates that assumed value of population parameter will not fall in confidence interval.
#
#
# * Error of margin used to calculate confidence interval, we add and subtract point estimate from margin of error to calculate the confidence interval.
#
#
# * If I said that my confidence level is 95% it means I'm 95% sure that my assumed value will fall under the confidence interval range but I'm 5% unsure about it, so that error of 5% is known as margin of error.

# %% [markdown]
# ### Q) What is Hypothesis testing?
#
# * Hypothesis test is a type of statistical test which is used to compare 2 two groups whether they are same or not.
#
#
# * Hypothesis test has 2 parameters which are null hypothesis and alternate hypothesis.

# %% [markdown]
#  ### Q) What is null hypotheis and alternative hypothesis?
#
# * Null hypothesis is a statement which states that population parameter is equal to sample statistic. Null hypothesis is denoted as H₀. (H not)
#
# EG: My assumption is splender plus gives more milege than pulsar, so null hypothesis statement would be splendor bike gives equal milegae to pulsar bike.
#
#
# * Alternate hypothesis is a statement  which states that population parameter is not equal to sample statistic or population paramter is greater than or lesser than sample statistic. Alternate Hypothesis is denoted as H₁ or Ha.
#
# Eg:- My assumption is splender plus bike gives more milege than pulsar bike. So, my statemnt would be this.
#
#
# Note:- Our aim is to find that whether the hypothesis test fails to reject null hypothesis or rejects null hypothesis.

# %% [markdown]
# ### Q) What is Parametric Test and Non-Parametric Test?
#
# * In parametric tests we compare sample statistic with the population parameter and parametric test assumes that sample data should be normally distributed.
#
#
# * In non-parameteric tests we compare anything about the population on the basis of sample data like distribution of data and there is no such assumption in non-parametric test that data should be normally distributed.

# %% [markdown]
# ### Q) What are the steps involve in Hyposthesis?
#
#     1) First we understand the research question.
#
#     2) Then we give the statement about Null and alternate hypothesis.
#
#     3) Then check what are the measurements which are given about sample and population.
#
#     4) According to that we choose the test.
#
#     5) Then Perform the test.
#
#     6) Then after seeing the result we decide to reject null hypothesis or fail to reject null hypothesis.

# %% [markdown]
# ### Q) What is significance value / level of significance / critical value?
#
# * Significance value is a range and threshold in which if our assumed value will fall we reject the null hypothesis.
#
#
# * We usually take significance value as 0.05, it means there is 5% probability that our assumed value will not fall in the confidence interval.
#
#
# * Significance value is also known as critical value, level of significance, rejection area of null hypothesis and denoted as alpha (α)

# %% [markdown]
# ![level-of-significance-and-hypothesis-testing.png](attachment:level-of-significance-and-hypothesis-testing.png)

# %% [markdown]
# ### Q) What is P-Value and it's significance?
#
# * P-Value is the probability value which is use to take the decision about hypothesis test.
#
#
# * If P-value is greater than significance value than we fail to reject null hypothesis and if P-value is lesser than and equal to significance value we reject the null hypothesis.
#
#
# * The motive of comparing P-value with significance value is to maintain a balance between Type I and Type II error.
#
#
# * When our assumed value is falls just near the crticial value we reject the null hypothesis in that case the chance of Type I error is increase which states that we reject the null hypothesis, when it is true, so to avoid from Type I error we use P-value. P-value increase the range of confidence interval so our chances of type I error should be less.
#
#
# Note:- When we increase the signification value so in that case the chance of Type II error will increase which states that we accept / fail to reject the null hypothesis when it is actually wrong. So to avoid from from Type I and Type II error we compare P-value with Significance value.

# %% [markdown]
# ### Q) What is one tail and two-tail test?
#
# * One tail test focus only on one side of alternate hyposesthis it means rejection area of null hypothesis is present only at one side.
#
#
#  Eg: My Alternative hypothesis statement is splendor bike gives more mileage than pulsar bike. So, in this statement we only focus on one side of the statement which is greater side.
#
#
# * Two tail test focus on both sides of alternate hypothesis, it means rejection area of null hypothesis is present at both sides.
#
#
#  Eg: My Alternative hypothesis statement is  mileage of Splendor bike and pulsar bike is not equal. So, in this statement we focus on both sides, greater side and lower sider. In two-tail test we have to find the confidence interval.
#
#
#  Note: The choice of one-tailed and two-tailed test depends on the research question.

# %% [markdown]
# ![1_3sjSfzKHmrUQ-yMeVKvk6w.gif](attachment:1_3sjSfzKHmrUQ-yMeVKvk6w.gif)

# %% [markdown]
# ### Q) What is type I and Type II error?
#
# Type I and Type II error occurs while making a decision about hypothesis test.
#
# * Type I error is also known as False Poitive it means we reject the null hypothesis when it is true.
#
#
# * Type II error is also known as False Negative it means we fail to reject null hypothesis when it is wrong.

# %% [markdown]
# ### Q) Where we use hypothesis testing in ML?
#
# Hypothesis Testing in ML:-
#
#
# 1. Model comparison Hypothesis testing can be used to compare the performance of different machine learning models or    algorithms on a given dataset. For example, you can use a paired t-test to compare the accuracy or error rate of two    models on multiple cross- validation folds to determine if one model performs significantly better than the other.
#
#
# 2. Feature selection: Hypothesis testing can help identify which features are significantly related to the target       variable or contribute meaningfully to the model's performance. For example, you can use a t-test, chi-square test, or       ANOVA to test the relationship between individual features and the target variable. Features with significant           relationships can be selected for building the model, while non-significant features may be excluded.
#
#
# 3. Hyperparameter tuning: Hypothesis testing can be used to evaluate the performance of a model trained with different    hyperparameter settings. By comparing the performance of models with different hyperparameters, you can determine if one set of hyperparameters leads to significantly better performance.
#
#
# 4. Assessing model assumptions: In some cases, machine learning models rely on certain statistical assumptions, such as linearity or normality of residuals in linear regression. Hypothesis testing can help assess whether these assumptions   are met, allowing you to determine if the model is appropriate for the data

# %% [markdown]
# ### Q) What is Z-Test?
#
# * Z-test is a type of parametric test which is use to compare the sample mean with the population mean.
#
#
# * We perform Z-Test when standard deviation of population is known or sample is greater than or equals to 30. Z-test is known as sigma known test.

# %% [markdown]
# ### Q) What is T-Test?
#
# * T-Test is a type of parametric test which is use to compare the mean of two groups.
#
#
# * We perform T-Test when standard deviation of population is not known or sample size is smaller than 30.
#
#
# We have 3 types of T-Test:-
#
#
# 1) One-Sample t-test is used to compare sample mean with the population mean.
#
#
# 2) Independent t-test (two-sample test) is used to compare mean of 2 categories of an independent variable with the mean of dependent variable.
#
#
# 3) Paired t-test is used to compare means of 2 related variables within the same samples.

# %% [markdown]
# ### Q) What is degree of freedom?
#
# * Degree of freedom is the number of independent observation that are used in a statistical analysis. Degree of freedom is represented as (df).
#
#
# * The formula of degree of freedom is 1-number of observation or in some scenarios the formula will be number of observations-number of variables.

# %% [markdown]
# ### Q) What is chi-sqaure test?
#
# * Chi-square test is a type of non-parametric used to compare the distribution of data between two categorical variables by using the observed and expected values of each category present in the variable.
#
#
# * In Chi-Square test we find the value of chi-square, if the chi-square value is greater than critical value we reject null hypothesis and if chi-square value is lesser than the critical we accept the null hypothesis.

# %% [markdown]
# ### Q) What is Anova test (F-Test)?
#
#
# * Anova stands for Analysis of Variance.It is a type of parametric test which is used to compare the mean of two or more than two groups by analyzing the variance of each variable and comparing it to the overall variance.
#
#
# There are 2 types of Annova Test:
#
# 1) One Way Anova:-It is used to compare the means of multiple categories of dependent variables to one independent variablependent variable.
#
#
# 2) Two way anova:- Two-way ANOVA is a statistical test used to analyze the effects of two independent variables on a dependent variable and determine if there are significant differences and interactions between them. It helps explore how different factors impact the outcome variable simultaneously.

# %% [markdown]
# ### Q) What is cumulative sum?
#
#
# * A cumulative sum is also known as a running total.
#
#
# * It is calculated by adding each value by the sum of previous value in a sequence.
#
#
# * Eg:- if the sequence is {1, 2, 3, 4}, the cumulative sum would be {1, 3, 6, 10}.

# %% [markdown]
# ### Q) What is Probability?
#
#
# * Probability is a measures which finds the chance of an event happening. The probability value ranges between 0-1. The value closer to 1 indicates the high chance of an event happening and value closer to 0 indicates low chance of an event happening. Probability is calculated by possible outcomes / total outcomes.

# %% [markdown]
# ![1659524526.Probability-Formula,-Definitions,-Examples,-and-More!.png](attachment:1659524526.Probability-Formula,-Definitions,-Examples,-and-More!.png)

# %% [markdown]
# ### Q) What is complimentary probability?
#
# * Complementary probability refers to the probability of an event not happening. Complimentary Probability is calculated by 1-possible outcomes / total outcomes.

# %% [markdown]
# ### Q) What is union and intersection?
#
# * Union means merging two sets of elements and make a new set of elements which contains only unique elements of both sets.
#
#
# * Insection means merging two sets of elements and make a new set of elements which contains only common elements between both sets.

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# ### Q) What is objective probability / classical probability?
#
# * Objective probability refers to the probability to an event happening on the basis of actual data or evidence.

# %% [markdown]
# ### Q) What is subjective probability / personal probability?
#
#
# * Subjective probability refers to probability of an event happening on the basis of individual's  opinion.

# %% [markdown]
# ### Q) What are the types of rule in proabability?
#
# We have 2 types of rule in probability:
#
#
# 1) Additive Rule (or rule): In additive rule we find probability of event A and event B by adding them. We have 2 types of additional rule.
#
#
# a) Addition Rule for Mutually Exclusive Events: This rule is apply to find the probability of Mutually Exclusive Events. Mutually Exclusive Events means either event A happening or event B happening, both are not happening together.
#
#
# b) Addition Rule for Non Mutually Exclusive Events: This rule is apply to find the probability of Non Mutually Exclusive Events.
# Non-Mutually Exclusive Events means both event A and event B happens together.
#
#
# 2) Multiplicative Rule (and Rule) / Joint Probability: In Multiplicative rule we find probability of 2 or more events happening together at same time by Multiplying their probabilities together.

# %% [markdown]
#     Mathematically, for mutually exclusive events:
#
#     P(A or B) = P(A) + P(B)
#
#     Question: For example, consider rolling a six-sided die. The probability of getting a 2 or a 4 is the sum of the individual probabilities:
#
#     P(2 or 4) = P(2) + P(4)
#               = 1/6 + 1/6
#               = 1/3
#               = 0.33

# %% [markdown]
#     Mathematically, for non-mutually exclusive events:
#
#     P(A or B) = P(A) + P(B) - P(A and B)
#
#     Question: For example, consider drawing a card from a standard deck of 52 cards. The probability of drawing either a heart or a king is the sum of their individual probabilities minus the probability of drawing the king of hearts:
#
#     P(heart or king) = P(heart) + P(king) - P(king of hearts)
#                          = 13/52 + 4/52 - 1/52
#                          = 16/52
#                          = 4/13
#                          = 0.30

# %% [markdown]
#     Mathematically, for Multiplicative Rule (and Rule):
#
#     Suppose we have a bag containing 4 red balls and 6 blue balls. We randomly draw two balls from the bag without replacement. We want to find the probability of selecting a red ball on the first draw and a blue ball on the second draw.
#
#     To solve this problem, we can apply the Multiplicative Rule as follows:
#
#     Probability of drawing a red ball on the first draw:
#     P(Red on 1st draw) = Number of red balls / Total number of balls
#                        = 4 / 10
#                        = 2 / 5
#
#     Probability of drawing a blue ball on the second draw, given that a red ball was drawn on the first draw:
#     P(Blue on 2nd draw | Red on 1st draw) = Number of blue balls / Remaining number of balls after the first draw
#                                           = 6 / 9
#                                           = 2 / 3
#
#     Applying the Multiplicative Rule (and Rule):
#     P(Red on 1st draw and Blue on 2nd draw) = P(Red on 1st draw) * P(Blue on 2nd draw | Red on 1st draw)
#                                             = (2 / 5) * (2 / 3)
#                                             = 4 / 15
#
#     Therefore, the probability of selecting a red ball on the first draw and a blue ball on the second draw is 4/15.

# %% [markdown]
# ### Q) What is independent and dependent events?

# %% [markdown]
# ![Screenshot%20%283%29.png](attachment:Screenshot%20%283%29.png)

# %% [markdown]
# ### Q) What is joint probability?
#
# Joint probability measures the probability of 2 or more events happening together at same point of time.

# %% [markdown]
# ### Q) What is conditional probability?
#
# * Conditional probability measures the probability of an event happening which is dependent on the probability of other event happening.

# %% [markdown]
# ### Q) What is baye's Theorem? Explain.
#
#
# * Baye's theorem is mathematical theorem which based on conditional probability. Bayes's theorem provides a convient way to calculate the probability of an event happening on the basis of events which already have been occured. It considers the knowledge and evidence of previously occured events and on the basis of that it calculates the probability of an new event happening.

# %% [markdown]
# ### Q) What is PDF (Probability density function)?
#
#
# * PDF stands for Probability density function, which is used to find the probability distribution of continuous variable.
#
#
# * In PDF we plot a distribution graph of data where y-axis represents the probability and ranges between 0-1, x-axis represents original values of data and distribution curves represents the probability of values occurring, when we choose a random value.
#
#
# * Eg: Normal distribution and standard normal distribution.

# %% [markdown]
# ### Q) What is PMF?
#
#
# * PMF stands for probability mass function, which is used to find the probability of discrete variable.
#
#
# * In PMF we plot a bar graph in which x-axis presents the original value of data and y-axis represents the probability and ranges between 0-1. Each bar represents the probability of values occuring, when we choose a random value.
#
#
# * Eg: Bernoulli Distribution, Binomial distribution and poission distribution.

# %% [markdown]
# ### Q) What is Bernoulli Distribution, Binomial distribution and poission distribution?
#
# These all are probability distributions:
#
#
# 1) Bernoulli Distribution is a type of probability distribution, which is used to find the probability of binary discrete variable and represent it on a bar graph, where x-axis contains only two values, 0 and 1 and y-axis represents the probability and each bar represets the probability of each category.
#
#
# 2) Binomial Distribution is a type of probability distribution, which is used to find the probability of discrete variable where multiple categories are present, it finds thye probability of each category and represents the probability on a bar graph. On bar graph x-axis shows the categories, y-axis represents the probability and ranges between 0-1 and each bar represents the probability of category.
#
#
# 3) Poission Distribution is used to find the probability of events between a fixed interval of time. Eg:- Find the probability of road accidents between 1 am to 5 am.

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# ![download%20%281%29.png](attachment:download%20%281%29.png)
